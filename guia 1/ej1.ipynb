# %% [markdown]
# # Guia 1

# %% [markdown]
# ### Ejercicio 1

# %%
#LIBRERIAS
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ##### Inciso 1

# %%
data = plt.imread('pikachu_vs_charmander.jpeg')
print(data)
print(np.shape(data))
values = (np.min(data, axis  = 2).astype(int) + np.max(data,  axis  = 2).astype(int) )/2
plt.imshow(values,   cmap = 'gray')
# Out:
# [[[ 47  32  63]
#   [ 49  34  65]
#   [ 50  35  68]
#   ...
#   [ 30  32  55]
#   [ 30  32  55]
#   [ 30  32  55]]
#
#  [[ 46  32  65]
#   [ 48  34  67]
#   [ 49  35  70]
#   ...
#   [ 30  32  55]
#   [ 30  32  55]
#   [ 30  32  55]]
#
#  [[ 44  34  69]
#   [ 46  36  71]
#   [ 47  37  72]
#   ...
#   [ 29  33  58]
#   [ 29  33  58]
#   [ 29  33  58]]
#
#  ...
#
#  [[ 34  45  99]
#   [ 35  46 100]
#   [ 36  47 101]
#   ...
#   [ 22  51 111]
#   [ 22  51 109]
#   [ 22  51 109]]
#
#  [[ 32  44  96]
#   [ 33  45  97]
#   [ 34  46  98]
#   ...
#   [ 22  51 111]
#   [ 22  51 109]
#   [ 22  51 107]]
#
#  [[ 30  42  94]
#   [ 31  43  95]
#   [ 32  44  96]
#   ...
#   [ 23  52 110]
#   [ 23  52 108]
#   [ 23  52 108]]]
# (256, 341, 3)

# %% [markdown]
# ##### Inciso 2

# %%
value = data.sum(axis=2) / 3

plt.imshow(value, cmap = 'gray')

# %% [markdown]
# ##### Inciso 3

# %%
R = data[:,:,0]
G = data[:,:,1]
B = data[:,:,2]

#values = (0* R+ 0 * G+ 1*B)

values = (0.3* R+ 0.59 * G+ 0.11*B)

plt.imshow(values, cmap = 'gray')

# %%
#Repaso

lista = [1,2,"hola",123,644,6788]

tupla = (11223, "hola") #No mutable

diccionario = {1, 3 , "hola"} #Son más rápidos


## ------------------------Slicing

#Listas
# Formato:         lista[start:stop:step] ---> no incluye el último

print(lista[1:3:2])
#invertir
print(lista[3:0:-1])
# Out:
# [2]
# [123, 'hola', 2]

# %% [markdown]
# # Numpy

# %%
arr1 = np.array ([1,2]) #Creo el array mediante una lista de python
arr2 = np.array ([1,2]) #Creo el array mediante una lista de python

print(arr1 @ arr2)

#El arroba: hace un producto escalar, la multiplicación de los arrays y suma el resultado del producto de las componentes 

# tensor: [M1, M2, M3] tiene N matrices de 2x2 como lo que se usan en las imagenes RGB
# La multiplicacion de tensores se da a lo largo de las ultimas dimensiones:
# (2,4,3) @ (2,3,4) = (2,4,4)
# Out:
# 5
